# %%
n = "10"

# %%
if len(n) % 2 == 1:
    a = n[0:len(n)//2+1]
    #print(a)
    print(a+a[:-1][::-1])
    
    b = str(int(a)+1)
    if len(b) == len(a):
        print(b+b[:-1][::-1])
    else:
        print(b[:len(b)//2+1] + b[:len(b)//2+1][::-1])
    
    c = str(int(a)-1)
    if len(c) == len(a):
        print(c+c[:-1][::-1])
    else:
        print(c[:len(c)//2+1] + c[:len(c)//2+1][::-1])

else:
    a = n[0:len(n)//2]
    print(a[:len(a)//2+1] + a[:len(a)//2+1][::-1])
    
    b = str(int(a)+1)
    if len(b) == len(a):
        print(b+b[::-1])
    else:
        print(b+b[:-1][::-1])
        
    c = str(int(a)-1)
    if len(c) == len(a):
        print(c+c[::-1])
    else:
        print(c+c[:-1][::-1])
# Out:
# 11
# 22
# 00

# %%
def solve(n):
    if n == "0":return "0"
    
    res = []
    if len(n) % 2 == 1:
        a = n[0:len(n)//2+1]

        c = str(int(a)-1)
        if len(c) == len(a):
            res.append(c+c[:-1][::-1])
        else:
            res.append("9"*(len(n) - 1))
        
        res.append(a+a[:-1][::-1])

        b = str(int(a)+1)
        if len(b) == len(a):
            res.append(b+b[:-1][::-1])
        else:
            res.append("1"+"0"*(len(n)-1)+"1")
            

        

    else:
        a = n[0:len(n)//2]
        
        c = str(int(a)-1)
        if len(c) == len(a) and c != "0":
            res.append(c+c[::-1])
        else:
            res.append("9"*(len(n)-1))
        
        res.append(a[:len(a)+1] + a[:len(a)+1][::-1])

        b = str(int(a)+1)
        if len(b) == len(a):
            res.append(b+b[::-1])
        else:
            res.append("1"+"0"*(len(n)-1)+"1")
    
    if n in res:res.remove(n)
    
    s = abs(int(res[0]) - int(n)) + 1
    r = ""
    n = 
    for p in res:
        if abs(int(p) - int(n)) < s:
            s = abs(int(p) - int(n))
            r = p
    
    return r

# %%
for i in range(10,1000):
    print(i, solve(str(i)))
# Out:
# ['9', '11', '22']
# 10 9
# ['9', '22']
# 11 9
# ['9', '11', '22']
# 12 11
# ['9', '11', '22']
# 13 11
# ['9', '11', '22']
# 14 11
# ['9', '11', '22']
# 15 11
# ['9', '11', '22']
# 16 11
# ['9', '11', '22']
# 17 22
# ['9', '11', '22']
# 18 22
# ['9', '11', '22']
# 19 22
# ['11', '22', '33']
# 20 22
# ['11', '22', '33']
# 21 22
# ['11', '33']
# 22 11
# ['11', '22', '33']
# 23 22
# ['11', '22', '33']
# 24 22
# ['11', '22', '33']
# 25 22
# ['11', '22', '33']
# 26 22
# ['11', '22', '33']
# 27 22
# ['11', '22', '33']
# 28 33
# ['11', '22', '33']
# 29 33
# ['22', '33', '44']
# 30 33
# ['22', '33', '44']
# 31 33
# ['22', '33', '44']
# 32 33
# ['22', '44']
# 33 22
# ['22', '33', '44']
# 34 33
# ['22', '33', '44']
# 35 33
# ['22', '33', '44']
# 36 33
# ['22', '33', '44']
# 37 33
# ['22', '33', '44']
# 38 33
# ['22', '33', '44']
# 39 44
# ['33', '44', '55']
# 40 44
# ['33', '44', '55']
# 41 44
# ['33', '44', '55']
# 42 44
# ['33', '44', '55']
# 43 44
# ['33', '55']
# 44 33
# ['33', '44', '55']
# ...

# %%
"abcdef"[:-1][::-1]
# Out:
# 'edcba'

# %%
"abcdef"[-2::-1]
# Out:
# 'edcba'
