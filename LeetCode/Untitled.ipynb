# %%
import torch
import matplotlib.pyplot as plt

# %%
a = torch.rand((3, 512, 512))

# %%
a.shape
# Out:
# torch.Size([3, 512, 512])

# %%
a = a.permute((2,1,0))

# %%
a.shape
# Out:
# torch.Size([512, 512, 3])

# %%
plt.imshow(a)
