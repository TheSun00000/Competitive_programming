# %%
def get_adj(i,n):
    adj = []
    if i < N: #the top
        if i % N == 0: #on the left
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i+N+1 < length: adj.append(loc(i+N+1,n, 1))
        elif i % N == N - 1: #on the right
            if 0 <= i-1 : adj.append(loc(i-1,n, -1))
            if i+N-1 < length  : adj.append(loc(i+N-1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
        else: #in the middle
            if 0 <= i-1 : adj.append(loc(i-1,n, -1))
            if i+N-1 < length  : adj.append(loc(i+N-1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i+N+1 < length: adj.append(loc(i+N+1,n, 1))
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            
            
        
        
    elif  length - N <= i: #the bottom
        if i % N == 0: #on the left
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N +1 >= 0 : adj.append(loc(i - N+1, n, -1))
        elif i % N == N - 1: #on the right
            if i-1 >= 0  : adj.append(loc(i-1,n, -1))
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N-1>= 0 : adj.append(loc(i - N-1, n, -1))
        else: #in the middle
            if i-1 >= 0  : adj.append(loc(i-1,n, -1))
            if i - N-1>= 0  : adj.append(loc(i - N-1, n, -1))
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i - N +1>= 0 : adj.append(loc(i - N+1, n, -1))
            
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            

    else:  # N < i <= length - N #the middle
        if i % N == 0: #on the left
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N +1>= 0 : adj.append(loc(i - N+1, n, -1))
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i+N+1 < length: adj.append(loc(i+N+1,n, 1))
            
        elif i % N == N - 1: #on the right
            if 0 <= i-1 : adj.append(loc(i-1,n, -1))
            if i+N-1 < length  : adj.append(loc(i+N-1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N-1>= 0 : adj.append(loc(i - N-1, n, -1))
        else: #in the middle
            if i - N-1>= 0 : adj.append(loc(i - N-1, n, -1))
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N +1>= 0 : adj.append(loc(i - N+1, n, -1))
            if i-1 >= 0  : adj.append(loc(i-1,n, -1))   
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i+N-1 < length  : adj.append(loc(i+N-1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i+N+1 < length: adj.append(loc(i+N+1,n, 1))
            
            
    
    return adj

# %%
def loc(i,n, mode):
    if mode == -1:
        while n != -1:
            #print(i, accum_pos[n], n)
            if (n == 0) or (i >= accum_pos[n-1]):
                return n
            else:
                n = n - 1
        return -1
    else:
        while n != len(accum_pos):
            #print(i, accum_pos[n], n)
            if i < accum_pos[n]:
                return n
            else:
                n = n + 1
        return -1

# %%
def process(start, end):
    global prev, c, output
    for p in range(start, end):
        adj = get_adj((old_pos + p ), n)
        current_max = 0
        for v in adj:
            cache = abs(values[v] - val)
            if cache > current_max:
                current_max = cache
        
        if (current_max != prev) and (c != 0):
            print("kkkkk",c)
            output = output +  str(prev) + " " + str(c) + " "
            c = 0

    
        prev = current_max
        c += 1
        
    return output

# %%
def edge_detection(image):
    global N, length, accum_pos, prev, c, output, old_pos, n, values, val
    image = image.split()
    
    N_pair = int((len(image) - 1 ) / 2)
    values = [int(image[1 + 2*n]) for n in range(N_pair)]
    positions = [int(image[1 + 2*n+1]) for n in range(N_pair)]
    length = sum(positions)
    N = int(image[0])
    
    c = 0
    accum_pos = []
    for n in range(N_pair):
        c = c + positions[n]
        accum_pos.append(c)
        
    output = str(N)+" "
    N_pair = int((len(image) - 1 ) / 2)
    old_pos = 0
    c = 0
    prev = -1
    
    i = 0
    for n in range(0, N_pair):
        #print(n)
        val, pos = values[n], positions[n]
        #print(i)
        if pos - (N - i % N ) < 3 * N:
            output = process(0, pos)
            old_pos += pos
        
        else: #pos - (N - i) >= 3 * N
            print(old_pos, pos, i)
            zeros = (pos-(N-i%N)) // N - 2
            print("zeros", zeros)
            output = process(0, 2*N - i%N)
            print("start", old_pos, "end", old_pos + 2*N - i%N - 1)
            
            current_max = 0
            if (current_max != prev) and (c != 0):
                #print(prev, c)
                output = output +  str(prev) + " " + str(c) + " "
                c = 0
            else:
                print("kkk")
                c = c + zeros*N
                print(c)
                
            #old_pos = old_pos +  N + (N-i+1) + zeros*N
            old_pos = N + (N-i%N) + zeros*N + i
            print("old_pos",old_pos)
            reste = pos - ( N + (N-i%N) + zeros*N)
            output = process(0, reste)
            print("start", old_pos , "end", old_pos + N + (N-i%N),"pos",pos,"\n")
            
            old_pos = pos
            
        
        i = accum_pos[n] +1
        
    
        
    if c != 0:
        output = output +  str(prev) + " " + str(c)
        
    return output.strip()

# %%
#%%timeit
image = '10 35 500000000 200 500000000'
#image = '7 15 4 100 15 25 2 175 2 25 5 175 2 25 5'

edge_detection(image)
# Out:
# 0 500000000 0
# zeros 49999997
# start 0 end 19
# kkk
# 499999990
# old_pos 499999990
# kkkkk 499999990
# start 499999990 end 500000010 pos 500000000
#
# 500000000 500000000 500000001
# zeros 49999997
# kkkkk 20
# start 500000000 end 500000018
# kkk
# 499999979
# old_pos 999999990
# start 999999990 end 1000000009 pos 500000000
# '10 0 499999990 165 20 0 499999990'

# %%
accum_pos
# Out:
# [4, 19, 21, 23, 28, 30, 35]

# %%
get_adj(34, 6)
# Out:
# [6, 4, 4]

# %%
def get_adj(i,n):
    adj = []
    if i < N: #the top
        if i % N == 0: #on the left
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i+N+1 < length: adj.append(loc(i+N+1,n, 1))
        elif i % N == N - 1: #on the right
            if 0 <= i-1 : adj.append(loc(i-1,n, -1))
            if i+N-1 < length  : adj.append(loc(i+N-1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
        else: #in the middle
            if 0 <= i-1 : adj.append(loc(i-1,n, -1))
            if i+N-1 < length  : adj.append(loc(i+N-1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i+N+1 < length: adj.append(loc(i+N+1,n, 1))
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            
            
        
        
    elif  length - N <= i: #the bottom
        if i % N == 0: #on the left
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N +1 >= 0 : adj.append(loc(i - N+1, n, -1))
        elif i % N == N - 1: #on the right
            if i-1 >= 0  : adj.append(loc(i-1,n, -1))
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N-1>= 0 : adj.append(loc(i - N-1, n, -1))
        else: #in the middle
            if i-1 >= 0  : adj.append(loc(i-1,n, -1))
            if i - N-1>= 0  : adj.append(loc(i - N-1, n, -1))
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i - N +1>= 0 : adj.append(loc(i - N+1, n, -1))
            
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            

    else:  # N < i <= length - N #the middle
        if i % N == 0: #on the left
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N +1>= 0 : adj.append(loc(i - N+1, n, -1))
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i+N+1 < length: adj.append(loc(i+N+1,n, 1))
            
        elif i % N == N - 1: #on the right
            if 0 <= i-1 : adj.append(loc(i-1,n, -1))
            if i+N-1 < length  : adj.append(loc(i+N-1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N-1>= 0 : adj.append(loc(i - N-1, n, -1))
        else: #in the middle
            if i - N-1>= 0 : adj.append(loc(i - N-1, n, -1))
            if i - N >= 0 : adj.append(loc(i - N, n, -1))
            if i - N +1>= 0 : adj.append(loc(i - N+1, n, -1))
            if i-1 >= 0  : adj.append(loc(i-1,n, -1))   
            if i+1 < length  : adj.append(loc(i+1,n, 1))
            if i+N-1 < length  : adj.append(loc(i+N-1,n, 1))
            if i+N < length  : adj.append(loc(i+N,n, 1))
            if i+N+1 < length: adj.append(loc(i+N+1,n, 1))
            
            
    
    return adj



def loc(i,n, mode):
    if mode == -1:
        while n != -1:
            #print(i, accum_pos[n], n)
            if (n == 0) or (i >= accum_pos[n-1]):
                return n
            else:
                n = n - 1
        return -1
    else:
        while n != len(accum_pos):
            #print(i, accum_pos[n], n)
            if i < accum_pos[n]:
                return n
            else:
                n = n + 1
        return -1
    
    
def process(start, end):
    global prev, c, output
    for p in range(start, end):
        adj = get_adj((old_pos + p ), n)
        current_max = 0
        for v in adj:
            cache = abs(values[v] - val)
            if cache > current_max:
                current_max = cache
        #print(old_pos + p , current_max,val, c)
        if (current_max != prev) and (c != 0):
            output = output +  str(prev) + " " + str(c) + " "
            c = 0

    
        prev = current_max
        c += 1
        
    return output



def edge_detection(image):
    global N, length, accum_pos, prev, c, output, old_pos, n, values, val
    image = image.split()
    
    N_pair = int((len(image) - 1 ) / 2)
    values = [int(image[1 + 2*n]) for n in range(N_pair)]
    positions = [int(image[1 + 2*n+1]) for n in range(N_pair)]
    length = sum(positions)
    N = int(image[0])
    
    c = 0
    accum_pos = []
    for n in range(N_pair):
        c = c + positions[n]
        accum_pos.append(c)
        
    output = str(N)+" "
    N_pair = int((len(image) - 1 ) / 2)
    old_pos = 0
    c = 0
    prev = -1
    
    i = 0
    for n in range(0, N_pair):
        print(n, i)
        val, pos = values[n], positions[n]
        if pos - (N - i % N ) < 3 * N:
            print("0000000000000000000000")
            output = process(0, pos)
            old_pos += pos
        
        else: #pos - (N - i) >= 3 * N
            print(old_pos, pos, i)
            print("1111111111111111111111", old_pos, pos, i)
            old_pos = i
            zeros = (pos-(N-i%N)) // N - 2
            #print("zeros", zeros)
            output = process(0, 2*N - i%N)
            print("start", old_pos, "end", old_pos + 2*N - i%N - 1)
            
            current_max = 0
            if (current_max != prev) and (c != 0):
                #print(prev, c)
                output = output +  str(prev) + " " + str(c) + " "
                c = 0
            else:
                #print("kkk")
                c = c + zeros*N
                #print(c)
                
            #old_pos = old_pos +  N + (N-i+1) + zeros*N
            old_pos = N + (N-i%N) + zeros*N + i
            #print("old_pos",old_pos)
            reste = pos - ( N + (N-i%N) + zeros*N)
            output = process(0, reste)
            #print("start", old_pos , "end", old_pos + N + (N-i%N),"pos",pos,"\n")
            
            old_pos = pos
            
        
        i = accum_pos[n]
        
    
        
    if c != 0:
        output = output +  str(prev) + " " + str(c)
        
    return output.strip()

# %%
#%%timeit
#image = '10 35 500000000 200 500000000'
#image = '7 15 4 100 15 25 2 175 2 25 5 175 2 25 5'

edge_detection("20 23 5654 10 5564 120 31 82 45 5 38 203 10 26 3533 116 33 161 40 48 47 1 16 168 3 159 17 29 5278 14 33 69 6 57 14 19 16 131 192 227 10")
#'10 17 2 0 8 17 2 0 28 17 22 0 38'
# Out:
# 0 0
# 0 5654 0
# 1111111111111111111111 0 5654 0
# start 0 end 39
# 1 5654
# 5654 5564 5654
# 1111111111111111111111 5654 5564 5654
# start 5654 end 5679
# 2 11218
# 0000000000000000000000
# 3 11249
# 0000000000000000000000
# 4 11294
# 0000000000000000000000
# 5 11332
# 0000000000000000000000
# 6 11342
# 5688 3533 11342
# 1111111111111111111111 5688 3533 11342
# start 11342 end 11379
# 7 14875
# 0000000000000000000000
# 8 14908
# 0000000000000000000000
# 9 14948
# 0000000000000000000000
# 10 14995
# 0000000000000000000000
# 11 15011
# 0000000000000000000000
# 12 15014
# 0000000000000000000000
# 13 15031
# 3689 5278 15031
# 1111111111111111111111 3689 5278 15031
# start 15031 end 15059
# 14 20309
# 0000000000000000000000
# 15 20342
# 0000000000000000000000
# 16 20348
# 0000000000000000000000
# 17 20362
# 0000000000000000000000
# 18 20378
# 5347 192 20378
# 1111111111111111111111 5347 192 20378
# start 20378 end 20399
# 19 20570
# 0000000000000000000000
# '20 0 5633 13 42 0 5522 110 21 97 31 59 45 18 35 5 3 193 10 177 1 21 8 177 12 0 3491 90 21 93 33 138 40 25 47 22 16 145 3 136 17 139 4 130 17 0 5236 15 21 9 33 46 6 34 14 4 16 112 1 74 2 112 18 0 150 96 11 0 9 96 1 204 10'

# %%
accum_pos
# Out:
# [1, 51, 100]

# %%
get_adj(50,1)
# Out:
# [1, 1, 2, 2, 2]
